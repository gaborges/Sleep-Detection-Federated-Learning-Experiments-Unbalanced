# %%
import csv
import json
import pandas as pd
from datetime import datetime
import numpy as np
from collections import Counter


import warnings
warnings.filterwarnings("ignore")


localFolder = "../data_2019_processed/"
baseFolder = "../../Dataset_ECUADOR_2019/"

# %%
# Dataframe of all datasets
# initialize list of lists
datasets = [['0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs'],
            ['0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA'], 
            ['2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0'], 
            ['2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys'], 
            #['5FLZBTVAPwdq9QezHE2sVCJIs7p+r6mCemA2gp9jATk'], #does not have the file
            ['7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA'], 
            ['a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4'], 
            ['ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc'], 
            ['Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U'], 
            ['CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA'], 
            ['DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc'], 
            ['DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA'], 
            ['dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY'], 
            ['HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo'], 
            ['jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw'], 
            ['JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I'], 
            ['K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8'], 
            ['oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q'], 
            ['pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM'], 
            ['PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc'], 
            ['QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ'], 
            ['rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw'], 
            ['RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI'], 
            ['SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4'], 
            ['VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is'], 
            ['Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw'], 
            ['XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA'], 
            ['YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw'], 
            ['ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM'], 
            ['ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY']]
  
# Create the pandas DataFrame
folders = pd.DataFrame(datasets, columns=['folder'])

#folders

# %%
timestamp = 0
# analyse the forms
allData = pd.DataFrame()
for indexFolder, folder in folders.iterrows():
   
    dataFLabel = pd.read_csv(localFolder+"form/sleep_form_"+folder['folder']+"_treated.csv",
                   delimiter=',', encoding="utf8")
    originalFLabel = pd.read_csv(baseFolder+folder['folder']+"/sleep_form_"+folder['folder']+".csv",
                   delimiter=',', encoding="utf8")
                                 
    print(folder['folder'])
    print("Original Count: ",originalFLabel.shape[0])
    print("New Count: ",dataFLabel.shape[0])
    print("Time sleep: ",dataFLabel['time_sleeping_hs'].max(),dataFLabel['time_sleeping_hs'].min(),dataFLabel['time_sleeping_hs'].mean())
    print("Sleep variability",)
    print("Count > 24:",dataFLabel[dataFLabel['time_sleeping_hs']>24].shape[0])
    print("Count <= 24 and > 12:",(dataFLabel[dataFLabel['time_sleeping_hs'] > 12 ].shape[0]-dataFLabel[dataFLabel['time_sleeping_hs']>24].shape[0]))
    print("Count <= 12:",dataFLabel[dataFLabel['time_sleeping_hs'] <= 12].shape[0])
    print("Count <= 0:",dataFLabel[dataFLabel['time_sleeping_hs'] <= 0].shape[0])
    print()
# Out:
# 0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs
# Original Count:  33
# New Count:  33
# Time sleep:  20.75333333333333 0.0 6.897390572390572
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 3
# Count <= 12: 30
# Count <= 0: 1
#
# 0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA
# Original Count:  31
# New Count:  31
# Time sleep:  22.50277777777778 2.5097222222222224 8.223960573476703
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 4
# Count <= 12: 27
# Count <= 0: 0
#
# 2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0
# Original Count:  48
# New Count:  48
# Time sleep:  16.0 0.0 5.026122685185185
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 1
# Count <= 12: 47
# Count <= 0: 1
#
# 2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys
# Original Count:  50
# New Count:  50
# Time sleep:  33.004444444444445 4.0 12.810561111111113
# Sleep variability
# Count > 24: 10
# Count <= 24 and > 12: 3
# Count <= 12: 37
# Count <= 0: 0
#
# 7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA
# Original Count:  15
# New Count:  15
# Time sleep:  31.511111111111116 3.262222222222222 8.271240740740742
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 0
# Count <= 12: 14
# Count <= 0: 0
#
# a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4
# Original Count:  50
# New Count:  50
# Time sleep:  33.509166666666665 3.25 18.18078888888889
# Sleep variability
# Count > 24: 23
# Count <= 24 and > 12: 6
# Count <= 12: 21
# Count <= 0: 0
#
# ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc
# Original Count:  22
# New Count:  22
# Time sleep:  20.004166666666663 3.0 8.12955808080808
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 2
# Count <= 12: 20
# Count <= 0: 0
#
# Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U
# Original Count:  53
# New Count:  53
# Time sleep:  32.0125 0.5 9.826184486373167
# Sleep variability
# Count > 24: 8
# Count <= 24 and > 12: 1
# Count <= 12: 44
# Count <= 0: 0
#
# CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA
# Original Count:  66
# New Count:  66
# Time sleep:  29.01388888888889 0.0 6.5538257575757575
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 1
# Count <= 12: 64
# Count <= 0: 2
#
# DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc
# Original Count:  22
# New Count:  22
# Time sleep:  14.0 2.0 7.425479797979798
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 1
# Count <= 12: 21
# Count <= 0: 0
#
# DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA
# Original Count:  6
# New Count:  6
# Time sleep:  18.003888888888888 0.7647222222222222 10.128657407407408
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 2
# Count <= 12: 4
# Count <= 0: 0
#
# dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY
# Original Count:  66
# New Count:  66
# Time sleep:  348.2575 4.264166666666666 15.453236531986532
# Sleep variability
# Count > 24: 3
# Count <= 24 and > 12: 14
# Count <= 12: 49
# Count <= 0: 0
#
# HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo
# Original Count:  49
# New Count:  49
# Time sleep:  30.50722222222222 1.0 9.00701814058957
# Sleep variability
# Count > 24: 5
# Count <= 24 and > 12: 1
# Count <= 12: 43
# Count <= 0: 0
#
# jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw
# Original Count:  28
# New Count:  28
# Time sleep:  29.25027777777778 3.0 7.447182539682539
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 1
# Count <= 12: 26
# Count <= 0: 0
#
# JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I
# Original Count:  52
# New Count:  52
# Time sleep:  18.26138888888889 3.5 6.59147435897436
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 2
# Count <= 12: 50
# Count <= 0: 0
#
# K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8
# Original Count:  42
# New Count:  42
# Time sleep:  32.76222222222222 3.0 7.939285714285715
# Sleep variability
# Count > 24: 2
# Count <= 24 and > 12: 0
# Count <= 12: 40
# Count <= 0: 0
#
# oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q
# Original Count:  50
# New Count:  50
# Time sleep:  102.7575 0.0 12.85045
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 20
# Count <= 12: 29
# Count <= 0: 2
#
# pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM
# Original Count:  22
# New Count:  22
# Time sleep:  26.76527777777778 3.0 8.595277777777776
# Sleep variability
# Count > 24: 2
# Count <= 24 and > 12: 1
# Count <= 12: 19
# Count <= 0: 0
#
# PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc
# Original Count:  9
# New Count:  9
# Time sleep:  712.0130555555555 5.5 85.39033950617284
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 0
# Count <= 12: 8
# Count <= 0: 0
#
# QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ
# Original Count:  28
# New Count:  28
# Time sleep:  30.010277777777777 5.25 9.718154761904762
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 5
# Count <= 12: 22
# Count <= 0: 0
#
# rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw
# Original Count:  19
# New Count:  19
# Time sleep:  32.26 1.75 11.650116959064327
# Sleep variability
# Count > 24: 4
# Count <= 24 and > 12: 0
# Count <= 12: 15
# Count <= 0: 0
#
# RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI
# Original Count:  40
# New Count:  40
# Time sleep:  30.51555555555556 0.25 7.345493055555556
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 2
# Count <= 12: 37
# Count <= 0: 0
#
# SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4
# Original Count:  20
# New Count:  20
# Time sleep:  9.016111111111112 1.0 5.288986111111112
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 0
# Count <= 12: 20
# Count <= 0: 0
#
# VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is
# Original Count:  38
# New Count:  38
# Time sleep:  316.2661111111111 1.0 25.511593567251463
# Sleep variability
# Count > 24: 6
# Count <= 24 and > 12: 0
# Count <= 12: 32
# Count <= 0: 0
#
# Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw
# Original Count:  24
# New Count:  24
# Time sleep:  17.760277777777777 4.0 8.772141203703704
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 3
# Count <= 12: 21
# Count <= 0: 0
#
# XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA
# Original Count:  35
# New Count:  35
# Time sleep:  32.515277777777776 3.5077777777777777 7.435063492063492
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 1
# Count <= 12: 33
# Count <= 0: 0
#
# YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw
# Original Count:  25
# New Count:  25
# Time sleep:  44.504444444444445 2.508611111111111 11.236799999999999
# Sleep variability
# Count > 24: 2
# Count <= 24 and > 12: 3
# Count <= 12: 20
# Count <= 0: 0
#
# ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM
# Original Count:  1
# New Count:  1
# Time sleep:  15.0 15.0 15.0
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 1
# Count <= 12: 0
# Count <= 0: 0
#
# ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY
# Original Count:  21
# New Count:  21
# Time sleep:  36.00944444444444 0.0 9.098465608465606
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 3
# Count <= 12: 17
# Count <= 0: 1

# %%
dataset = pd.read_csv(localFolder+"allData.csv")

# %%
dataset['timestamp2'].min()
# Out:
# 1526043855
